# %% [markdown]
# ## Check NVIDIA Driver and CUDA Runtime

# %%
# !nvidia-smi --version
# !nvcc --version
# Out:
# NVIDIA-SMI version  : 580.105.07
# NVML version        : 580.105
# DRIVER version      : 581.80
# CUDA Version        : 13.0
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2025 NVIDIA Corporation
# Built on Fri_Feb_21_20:23:50_PST_2025
# Cuda compilation tools, release 12.8, V12.8.93
# Build cuda_12.8.r12.8/compiler.35583870_0

# %% [markdown]
# ## Check Darknet Build status

# %%
# !darknet --version
# !DarkHelp --version
# Check Multi-arch build
# !cuobjdump --list-elf /usr/local/bin/darknet
# Out:
# Darknet V5 "Moonlit" v5.1-79-ge687086b
# CUDA runtime version 12080 (v12.8), driver version 13000 (v13.0)
# cuDNN version 12080 (v9.8.0), use of half-size floats is ENABLED
# => 0: NVIDIA GeForce RTX 3080 Ti [#8.6], 12.0 GiB
# => 1: NVIDIA GeForce RTX 3060 [#8.6], 12.0 GiB
# Protobuf 3.21.12, OpenCV 4.6.0, Ubuntu 24.04, wsl
# DarkHelp v1.9.7-1
# Darknet v5.1.79
#
# Darknet V5 "Moonlit" v5.1-79-ge687086b
# CUDA runtime version 12080 (v12.8), driver version 13000 (v13.0)
# cuDNN version 12080 (v9.8.0), use of half-size floats is ENABLED
# => 0: NVIDIA GeForce RTX 3080 Ti [#8.6], 12.0 GiB
# => 1: NVIDIA GeForce RTX 3060 [#8.6], 12.0 GiB
# Protobuf 3.21.12, OpenCV 4.6.0, Ubuntu 24.04, wsl
# ELF file    1: darknet.1.sm_52.cubin
# ELF file    2: darknet.2.sm_75.cubin
# ELF file    3: darknet.3.sm_80.cubin
# ELF file    4: darknet.4.sm_86.cubin
# ELF file    5: darknet.5.sm_89.cubin
# ELF file    6: darknet.6.sm_90.cubin
# ELF file    7: darknet.7.sm_120.cubin
# ELF file    8: darknet.8.sm_52.cubin
# ELF file    9: darknet.9.sm_75.cubin
# ELF file   10: darknet.10.sm_80.cubin
# ELF file   11: darknet.11.sm_86.cubin
# ELF file   12: darknet.12.sm_89.cubin
# ELF file   13: darknet.13.sm_90.cubin
# ELF file   14: darknet.14.sm_120.cubin
# ELF file   15: darknet.15.sm_52.cubin
# ELF file   16: darknet.16.sm_75.cubin
# ELF file   17: darknet.17.sm_80.cubin
# ELF file   18: darknet.18.sm_86.cubin
# ELF file   19: darknet.19.sm_89.cubin
# ELF file   20: darknet.20.sm_90.cubin
# ELF file   21: darknet.21.sm_120.cubin
# ELF file   22: darknet.22.sm_52.cubin
# ELF file   23: darknet.23.sm_75.cubin
# ELF file   24: darknet.24.sm_80.cubin
# ELF file   25: darknet.25.sm_86.cubin
# ELF file   26: darknet.26.sm_89.cubin
# ELF file   27: darknet.27.sm_90.cubin
# ELF file   28: darknet.28.sm_120.cubin
# ELF file   29: darknet.29.sm_52.cubin
# ELF file   30: darknet.30.sm_75.cubin
# ELF file   31: darknet.31.sm_80.cubin
# ELF file   32: darknet.32.sm_86.cubin
# ELF file   33: darknet.33.sm_89.cubin
# ELF file   34: darknet.34.sm_90.cubin
# ELF file   35: darknet.35.sm_120.cubin
# ELF file   36: darknet.36.sm_52.cubin
# ELF file   37: darknet.37.sm_75.cubin
# ELF file   38: darknet.38.sm_80.cubin
# ELF file   39: darknet.39.sm_86.cubin
# ELF file   40: darknet.40.sm_89.cubin
# ELF file   41: darknet.41.sm_90.cubin
# ELF file   42: darknet.42.sm_120.cubin
# ELF file   43: darknet.43.sm_52.cubin
# ELF file   44: darknet.44.sm_75.cubin
# ELF file   45: darknet.45.sm_80.cubin
# ELF file   46: darknet.46.sm_86.cubin
# ELF file   47: darknet.47.sm_89.cubin
# ELF file   48: darknet.48.sm_90.cubin
# ELF file   49: darknet.49.sm_120.cubin
# ELF file   50: darknet.50.sm_52.cubin
# ELF file   51: darknet.51.sm_75.cubin
# ELF file   52: darknet.52.sm_80.cubin
# ELF file   53: darknet.53.sm_86.cubin
# ELF file   54: darknet.54.sm_89.cubin
# ELF file   55: darknet.55.sm_90.cubin
# ELF file   56: darknet.56.sm_120.cubin
# ELF file   57: darknet.57.sm_52.cubin
# ELF file   58: darknet.58.sm_75.cubin
# ELF file   59: darknet.59.sm_80.cubin
# ELF file   60: darknet.60.sm_86.cubin
# ELF file   61: darknet.61.sm_89.cubin
# ELF file   62: darknet.62.sm_90.cubin
# ELF file   63: darknet.63.sm_120.cubin
# ELF file   64: darknet.64.sm_52.cubin
# ELF file   65: darknet.65.sm_75.cubin
# ELF file   66: darknet.66.sm_80.cubin
# ELF file   67: darknet.67.sm_86.cubin
# ELF file   68: darknet.68.sm_89.cubin
# ELF file   69: darknet.69.sm_90.cubin
# ELF file   70: darknet.70.sm_120.cubin

# %% [markdown]
# ## Test Darknet

# %%
# We use cfg files and test image of darknet repo 
# !git clone https://codeberg.org/CCodeRun/darknet.git
# %cd darknet
# Download weights file
# !wget --no-clobber https://github.com/hank-ai/darknet/releases/download/v2.0/yolov4-tiny.weights
# Run Darknet
# !darknet detector test --dont-show cfg/coco.data cfg/yolov4-tiny.cfg yolov4-tiny.weights artwork/dog.jpg
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 21445, done.
# remote: Counting objects: 100% (21445/21445), done.
# remote: Compressing objects: 100% (6249/6249), done.
# remote: Total 21445 (delta 15092), reused 21145 (delta 14839), pack-reused 0 (from 0)
# Receiving objects: 100% (21445/21445), 21.14 MiB | 6.51 MiB/s, done.
# Resolving deltas: 100% (15092/15092), done.
# Updating files: 100% (319/319), done.
# /workspace/darknet
# --2025-12-21 09:39:17--  https://github.com/hank-ai/darknet/releases/download/v2.0/yolov4-tiny.weights
# Resolving github.com (github.com)... 20.200.245.247
# Connecting to github.com (github.com)|20.200.245.247|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://release-assets.githubusercontent.com/github-production-release-asset/642508441/5c526108-47f1-4e75-a7a7-6670ba59aac9?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-21T10%3A32%3A12Z&rscd=attachment%3B+filename%3Dyolov4-tiny.weights&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-21T09%3A31%3A22Z&ske=2025-12-21T10%3A32%3A12Z&sks=b&skv=2018-11-09&sig=ZJQNusLcqeRlgMmEoiiRjdQOHh58p1xEUfUUuLv8Sx4%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NjMxMTc1OCwibmJmIjoxNzY2MzA5OTU4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.B2IzXzYZ8-I_wcWCHKdXh5xlLIR38hgWJiZ5DVmBAGg&response-content-disposition=attachment%3B%20filename%3Dyolov4-tiny.weights&response-content-type=application%2Foctet-stream [following]
# --2025-12-21 09:39:17--  https://release-assets.githubusercontent.com/github-production-release-asset/642508441/5c526108-47f1-4e75-a7a7-6670ba59aac9?sp=r&sv=2018-11-09&sr=b&spr=https&se=2025-12-21T10%3A32%3A12Z&rscd=attachment%3B+filename%3Dyolov4-tiny.weights&rsct=application%2Foctet-stream&skoid=96c2d410-5711-43a1-aedd-ab1947aa7ab0&sktid=398a6654-997b-47e9-b12b-9515b896b4de&skt=2025-12-21T09%3A31%3A22Z&ske=2025-12-21T10%3A32%3A12Z&sks=b&skv=2018-11-09&sig=ZJQNusLcqeRlgMmEoiiRjdQOHh58p1xEUfUUuLv8Sx4%3D&jwt=eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJpc3MiOiJnaXRodWIuY29tIiwiYXVkIjoicmVsZWFzZS1hc3NldHMuZ2l0aHVidXNlcmNvbnRlbnQuY29tIiwia2V5Ijoia2V5MSIsImV4cCI6MTc2NjMxMTc1OCwibmJmIjoxNzY2MzA5OTU4LCJwYXRoIjoicmVsZWFzZWFzc2V0cHJvZHVjdGlvbi5ibG9iLmNvcmUud2luZG93cy5uZXQifQ.B2IzXzYZ8-I_wcWCHKdXh5xlLIR38hgWJiZ5DVmBAGg&response-content-disposition=attachment%3B%20filename%3Dyolov4-tiny.weights&response-content-type=application%2Foctet-stream
# Resolving release-assets.githubusercontent.com (release-assets.githubusercontent.com)... 185.199.111.133, 185.199.110.133, 185.199.108.133, ...
# Connecting to release-assets.githubusercontent.com (release-assets.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 24251276 (23M) [application/octet-stream]
# Saving to: ‘yolov4-tiny.weights’
#
# yolov4-tiny.weights 100%[===================>]  23.13M  34.9MB/s    in 0.7s
#
# 2025-12-21 09:39:18 (34.9 MB/s) - ‘yolov4-tiny.weights’ saved [24251276/24251276]
#
# Darknet V5 "Moonlit" v5.1-79-ge687086b
# CUDA runtime version 12080 (v12.8), driver version 13000 (v13.0)
# cuDNN version 12080 (v9.8.0), use of half-size floats is ENABLED
# => 0: NVIDIA GeForce RTX 3080 Ti [#8.6], 12.0 GiB
# => 1: NVIDIA GeForce RTX 3060 [#8.6], 12.0 GiB
# Protobuf 3.21.12, OpenCV 4.6.0, Ubuntu 24.04, wsl
# WARNING: unusual number of classes (80) in cfg/coco.data
# WARNING: file /home/pjreddie/data/coco/trainvalno5k.txt does not seem to exist ("train=...") in cfg/coco.data
# WARNING: file coco_testdev does not seem to exist ("valid=...") in cfg/coco.data
# WARNING: "/home/pjreddie/backup/" does not seem to be a valid directory for "backup=..." in cfg/coco.data
# WARNING: unexpected option "eval=coco" in cfg/coco.data
# 0: compute_capability=860, cudnn_half=1, GPU=NVIDIA GeForce RTX 3080 Ti
# Allocating workspace to transfer between CPU and GPU:  9.7 MiB
# Detection layer #30 is type 17 (yolo)
# Detection layer #37 is type 17 (yolo)
# bicycle	c=60.315575%	x=71	y=100	w=506	h=379
# dog	c=83.628822%	x=137	y=206	w=181	h=332
# truck	c=78.710052%	x=464	y=80	w=242	h=91
# car	c=44.953178%	x=473	y=82	w=225	h=92

# %% [markdown]
# ## Test DarkHelp

# %%
# !DarkHelp --json --autohide off --keep --duration off --fontscale 0.7 --line 5 --shade 0.25 --threshold 0.5 --outdir . cfg/yolov4-tiny.cfg cfg/coco.names yolov4-tiny.weights artwork/dog.jpg
# Out:
# -> config file:  cfg/yolov4-tiny.cfg
# -> weights file: yolov4-tiny.weights
# -> names file:   cfg/coco.names
# -> driver:       Darknetd
# 0: compute_capability=860, cudnn_half=1, GPU=NVIDIA GeForce RTX 3080 Ti
# Allocating workspace to transfer between CPU and GPU:  9.7 MiB
# -> loading network took 1095.589 milliseconds
# -> neural network dimensions: 416x416
# -> output directory: .
# -> looking for image and video files
# -> found 1 file
# setting message: "press 'h' for help"
# #1/1: loading "artwork/dog.jpg"
# -> prediction took 133.596 milliseconds
# -> prediction results: 3
# -> 1/3: "bicycle 61%" #1 prob=0.605712 x=72 y=100 w=505 h=379 oid=0 tile=0 entries=1
# -> 2/3: "truck 81%" #7 prob=0.814976 x=464 y=80 w=240 h=91 oid=0 tile=0 entries=1
# -> 3/3: "dog 87%" #16 prob=0.869840 x=137 y=206 w=182 h=336 oid=0 tile=0 entries=1
# -> annotated image saved to "./dog.png"
# JSON OUTPUT
# {
#     "argv": "DarkHelp --json --autohide off --keep --duration off --fontscale 0.7 --line 5 --shade 0.25 --threshold 0.5 --outdir . cfg/yolov4-tiny.cfg cfg/coco.names yolov4-tiny.weights artwork/dog.jpg",
#     "file": [
#         {
#             "annotated_image": "./dog.png",
#             "count": 3,
#             "duration": "133.596 milliseconds",
#             "filename": "artwork/dog.jpg",
#             "original_height": 576,
#             "original_width": 768,
#             "prediction": [
#                 {
#                     "all_probabilities": [
#                         {
#                             "class": 1,
#                             "name": "bicycle",
#                             "probability": 0.6057115793228149
#                         }
#                     ],
#                     "best_class": 1,
#                     "best_probability": 0.6057115793228149,
#                     "name": "bicycle 61%",
#                     "original_point": {
#                         "x": 0.4220781922340393,
#                         "y": 0.5027536749839783
#                     },
#                     "original_size": {
#                         "height": 0.6584340929985046,
#                         "width": 0.6575674414634705
#                     },
#                     "prediction_index": 0,
#                     "rect": {
#                         "height": 379,
#                         "width": 505,
#                         "x": 72,
#                         "y": 100
#                     }
#                 },
#                 {
#                     "all_probabilities": [
#                         {
#                             "class": 7,
#                             "name": "truck",
#                             "probability": 0.8149755001068115
#                         }
#                     ],
#                     "best_class": 7,
#                     "best_probability": 0.8149755001068115,
#                     "name": "truck 81%",
#                     "original_point": {
#                         "x": 0.7607144117355347,
#                         "y": 0.21738497912883759
#                     },
#                     "original_size": {
#                         "height": 0.15820999443531036,
#                         "width": 0.31220322847366333
#                     },
#                     "prediction_index": 1,
#                     "rect": {
#                         "height": 91,
#                         "width": 240,
#                         "x": 464,
#                         "y": 80
#                     }
#                 },
#                 {
#                     "all_probabilities": [
#                         {
#                             "class": 16,
#                             "name": "dog",
#                             "probability": 0.8698399066925049
#                         }
#                     ],
#                     "best_class": 16,
#                     "best_probability": 0.8698399066925049,
#                     "name": "dog 87%",
#                     "original_point": {
#                         "x": 0.2971382439136505,
#                         "y": 0.6486819982528687
#                     },
#                     "original_size": {
#                         "height": 0.5841699242591858,
#                         "width": 0.2375105321407318
#                     },
#                     "prediction_index": 2,
#                     "rect": {
#                         "height": 336,
#                         "width": 182,
#                         "x": 137,
#                         "y": 206
#                     }
#                 }
#             ],
#             "resized_height": 576,
#             "resized_width": 768,
#             "tiles": {
#                 "height": 416,
#                 "horizontal": 1,
#                 "vertical": 1,
#                 "width": 416
#             },
#             "timestamp": {
#                 "epoch": 1766309965,
#                 "nanoseconds": 1766309965035465163,
#                 "text": "2025-12-21 09:39:25 +0000"
#             },
#             "type": "image/jpeg"
#         }
#     ],
#     "network": {
#         "cfg": "cfg/yolov4-tiny.cfg",
#         "loading": "1095.589 milliseconds",
#         "names": "cfg/coco.names",
#         "weights": "yolov4-tiny.weights"
#     },
#     "settings": {
#         "driver": "darknet",
#         "enable_tiles": false,
#         "force_greyscale": false,
#         "hierarchy": 0.5,
#         "include_percentage": true,
#         "keep_annotations": true,
#         "nms": 0.44999998807907104,
#         "outdir": ".",
#         "output_redirection": false,
#         "snapping": false,
#         "threshold": 0.5
#     },
#     "timestamp": {
#         "epoch": 1766309963,
#         "text": "2025-12-21 09:39:23 +0000"
#     }
# }
